# %%
import pandas as pd

# %%
data_path = r"/Users/evanlynch/Developer/DC-PINNs/src/gs_wamol/data/processed_data/wti_analysis_ready.csv"

# %%
df = pd.read_csv(data_path)
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22985 entries, 0 to 22984
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      22985 non-null  str
#  1   contract  22985 non-null  str
#  2   ric       22985 non-null  str
#  3   tau       22985 non-null  float64
#  4   settle    22985 non-null  float64
#  5   volume    22958 non-null  float64
#  6   expiry    22985 non-null  str
#  7   spot      22977 non-null  float64
#  8   rate      22977 non-null  float64
# dtypes: float64(5), str(4)
# memory usage: 1.6 MB
#          date contract     ric       tau  settle   volume      expiry   spot  \
# 0  2015-01-02  CLH2015  CLH5^1  0.134247   53.11  66396.0  2015-02-20  52.69
# 1  2015-01-02  CLM2015  CLM5^1  0.375342   55.15  28953.0  2015-05-19  52.69
# 2  2015-01-02  CLU2015  CLU5^1  0.630137   57.07   2980.0  2015-08-20  52.69
# 3  2015-01-02  CLZ2015  CLZ5^1  0.882192   59.05  16219.0  2015-11-20  52.69
# ...
